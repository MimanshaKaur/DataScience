# %%
marks = 80
if marks>=90:
    print('A+')
if marks>=70:
    print('A')
if marks>=60:
    print('B')
if marks <60:
    print('Poor Performance')
# Out:
# A
# B

# %%
marks = 80
if marks>=90:
    print('A+')
elif marks>=70:
    print('A')
elif marks>=60:
    print('B')
elif marks <60:
    print('Poor Performance')
else:
    print('Invalid Marks')
# Out:
# A

# %%
age = int(input("Enter the age "))
if age>=18:
    print("person is eligible to vote")
else:
    print("person is not eligible to vote")
# Out:
# person is not eligible to vote

# %%
# enter a character from user and check whether it is a vowel or not
ch = input("Enter a character ")
vowel = ['a','e','i','o','u']
if ch in vowel:
    print("It is a vowel")
else:
    print("It is not a vowel")
# Out:
# It is not a vowel

# %%
ch = input("Enter a character ")
if ch == 'a' or ch == 'e' or ch == 'i' or ch == 'o' or ch == 'u':
    print("It is a vowel")
else:
    print("It is not a vowel")
# Out:
# It is not a vowel

# %%
num = int(input("Enter a number "))
if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
s1=4
s2=4
s3=4
if s1 == s2 == s3:
    print('equilateral triangle')
elif s1 == s2 or s1 == s3 or s2 ==s3:
    print('Isosceles triangle') 
else:
    print('Scalene triangle')
# Out:
# equilateral triangle

# %%
username= input('enter the username: ')
email = input('enter your email: ')
password= input('enter your password: ')
cpassword= input('enter to confirm your password')
if len(username)>5 and len(username)<15:
    if '@' in email:
        if len(password)>=6 and len(password)<15:
            if password == cpassword:
                print('Registratoion is Successful....😊😊')
            else:
                print('Password and Confirm Password should be same...')
        else:
            print('Password is Incorrect...😒')
    else:
        print('Email is Incorrect...😒')
else:
    print('Username is Incorrect...😒')
# Out:
# Registratoion is Successful....😊😊
